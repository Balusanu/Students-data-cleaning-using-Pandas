# %% [markdown]
# ## Data cleaning - Students' data

# %% [markdown]
# Data cleaning steps that we are going to follow:
# 1) Deleting redundant columns
# 2) Renaming columns
# 3) Dropping duplicates
# 4) Remove NaN(null) values from the dataset
# 5) Check for some more transformations

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
data = pd.read_csv(r"C:\Users\balus\OneDrive\Desktop\Projects\Data cleaning - Pandas-student info\Students_info_data.csv")

# %%
data
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0           none             married     regularly          yes         3.0
# 1            NaN             married     sometimes          yes         0.0
# 2           none              single     sometimes          yes         4.0
# 3           none             married         never           no         1.0
# 4           none             married     sometimes          yes         0.0
# ...          ...                 ...           ...          ...         ...
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 15 columns]

# %%
data.shape ## Data contains 15 columns & 30641 rows
# Out:
# (30641, 15)

# %%
data.columns ## These are the names of the 15 columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
data.head() ## This shows the first 5 rows along with column names
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 2            < 5         87            93            91
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75

# %%
data.info() ## It is showing datatypes, no of non-null entries & various other info about each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 3.5+ MB

# %%
'''1) Deleting redundant columns
'Unnamed: 0','TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild' - 
These are the redundant columns (not so important columns) that we are deleting'''
data.drop(columns=['Unnamed: 0','TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild'],inplace=True)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  NrSiblings  \
# 0      female         NaN   bachelor's degree      standard         3.0
# 1      female     group C        some college      standard         0.0
# 2      female     group B     master's degree      standard         4.0
# 3        male     group A  associate's degree  free/reduced         1.0
# 4        male     group C        some college      standard         0.0
# ...       ...         ...                 ...           ...         ...
# 30636  female     group D         high school      standard         2.0
# 30637    male     group E         high school      standard         1.0
# 30638  female         NaN         high school  free/reduced         1.0
# 30639  female     group D  associate's degree      standard         3.0
# 30640    male     group B        some college      standard         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 10 columns]

# %%
'''2) Renaming columns, we are going to rename column NrSiblings as Numberofsiblings '''
data.rename(columns={"NrSiblings":"Noofsiblings"},inplace=True)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  Noofsiblings  \
# 0      female         NaN   bachelor's degree      standard           3.0
# 1      female     group C        some college      standard           0.0
# 2      female     group B     master's degree      standard           4.0
# 3        male     group A  associate's degree  free/reduced           1.0
# 4        male     group C        some college      standard           0.0
# ...       ...         ...                 ...           ...           ...
# 30636  female     group D         high school      standard           2.0
# 30637    male     group E         high school      standard           1.0
# 30638  female         NaN         high school  free/reduced           1.0
# 30639  female     group D  associate's degree      standard           3.0
# 30640    male     group B        some college      standard           1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 10 columns]

# %%
'''3) Dropping duplicates - we are going to check how many duplicate records are there & delete them'''
data.duplicated()
# Out:
# np.int64(9)

# %%
data.duplicated().sum() ## There are 9 duplicate rows in the data
# Out:
# np.int64(9)

# %%
data.drop_duplicates(inplace=True) ## deleting those duplicate rows

# %%
data.duplicated().sum() ## now there are no duplicate rows
# Out:
# np.int64(0)

# %%
'''4) Remove NaN(null) values from the dataset - we are going to find Null values & remove them'''
data.isna() ## Showing True wherever there is null values & false wherever there non-null values
# Out:
#        Gender  EthnicGroup  ParentEduc  LunchType  Noofsiblings  \
# 0       False         True       False      False         False
# 1       False        False       False      False         False
# 2       False        False       False      False         False
# 3       False        False       False      False         False
# 4       False        False       False      False         False
# ...       ...          ...         ...        ...           ...
# 30635   False        False       False      False         False
# 30636   False        False       False      False         False
# 30637   False        False       False      False         False
# 30638   False         True       False      False         False
# 30639   False        False       False      False         False
#
#        TransportMeans  WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0               False           False      False         False         False
# 1                True           False      False         False         False
# 2               False           False      False         False         False
# 3                True           False      False         False         False
# 4               False           False      False         False         False
# ...               ...             ...        ...           ...           ...
# 30635           False           False      False         False         False
# 30636           False           False      False         False         False
# 30637           False           False      False         False         False
# 30638           False           False      False         False         False
# 30639           False           False      False         False         False
#
# [30632 rows x 10 columns]

# %%
data.isna().sum() ## Shows No of null values column wise
# Out:
# Gender               0
# EthnicGroup       1840
# ParentEduc        1845
# LunchType            0
# Noofsiblings      1571
# TransportMeans    3134
# WklyStudyHours     955
# MathScore            0
# ReadingScore         0
# WritingScore         0
# dtype: int64

# %%
data.isna().sum().sum() ##Shows total No of null values across all columns
# Out:
# np.int64(9345)

# %%
data.dropna(inplace=True) ## removing null records & saving it

# %%
data.isna().sum().sum() ## now there are no null values
# Out:
# np.int64(0)

# %%
## 5) Check for some more transformations
data["Gender"].unique() ## checking unique entries in Gender column
# Out:
# array(['female', 'male'], dtype=object)

# %%
## Changing the gender values to 1 for female & 0 for male
data["Gender"] = data["Gender"].apply(lambda x:1 if x == "female" else 0)

# %%
data ## we can see Index is not right order
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  Noofsiblings  \
# 2           1     group B     master's degree      standard           4.0
# 4           0     group C        some college      standard           0.0
# 5           1     group B  associate's degree      standard           1.0
# 6           1     group B        some college      standard           1.0
# 7           0     group B        some college  free/reduced           1.0
# ...       ...         ...                 ...           ...           ...
# 30634       0     group A  associate's degree  free/reduced           2.0
# 30635       0     group C        some college      standard           2.0
# 30636       1     group D         high school      standard           2.0
# 30637       0     group E         high school      standard           1.0
# 30639       1     group D  associate's degree      standard           3.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 2         school_bus            < 5         87            93            91
# 4         school_bus         5 - 10         76            78            75
# 5         school_bus         5 - 10         73            84            79
# 6            private         5 - 10         85            93            89
# 7            private           > 10         41            43            39
# ...              ...            ...        ...           ...           ...
# 30634     school_bus         5 - 10         65            60            60
# 30635     school_bus         5 - 10         58            53            49
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30639     school_bus         5 - 10         82            90            93
#
# [22343 rows x 10 columns]

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  Noofsiblings  \
# 2           1     group B     master's degree      standard           4.0
# 4           0     group C        some college      standard           0.0
# 5           1     group B  associate's degree      standard           1.0
# 6           1     group B        some college      standard           1.0
# 7           0     group B        some college  free/reduced           1.0
# ...       ...         ...                 ...           ...           ...
# 30634       0     group A  associate's degree  free/reduced           2.0
# 30635       0     group C        some college      standard           2.0
# 30636       1     group D         high school      standard           2.0
# 30637       0     group E         high school      standard           1.0
# 30639       1     group D  associate's degree      standard           3.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 2         school_bus            < 5         87            93            91
# 4         school_bus         5 - 10         76            78            75
# 5         school_bus         5 - 10         73            84            79
# 6            private         5 - 10         85            93            89
# 7            private           > 10         41            43            39
# ...              ...            ...        ...           ...           ...
# 30634     school_bus         5 - 10         65            60            60
# 30635     school_bus         5 - 10         58            53            49
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30639     school_bus         5 - 10         82            90            93
#
# [22343 rows x 10 columns]

# %%
data.drop(columns="index",inplace=True)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  Noofsiblings  \
# 0           1     group B     master's degree      standard           4.0
# 1           0     group C        some college      standard           0.0
# 2           1     group B  associate's degree      standard           1.0
# 3           1     group B        some college      standard           1.0
# 4           0     group B        some college  free/reduced           1.0
# ...       ...         ...                 ...           ...           ...
# 22338       0     group A  associate's degree  free/reduced           2.0
# 22339       0     group C        some college      standard           2.0
# 22340       1     group D         high school      standard           2.0
# 22341       0     group E         high school      standard           1.0
# 22342       1     group D  associate's degree      standard           3.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         87            93            91
# 1         school_bus         5 - 10         76            78            75
# 2         school_bus         5 - 10         73            84            79
# 3            private         5 - 10         85            93            89
# 4            private           > 10         41            43            39
# ...              ...            ...        ...           ...           ...
# 22338     school_bus         5 - 10         65            60            60
# 22339     school_bus         5 - 10         58            53            49
# 22340     school_bus         5 - 10         59            61            65
# 22341        private         5 - 10         58            53            51
# 22342     school_bus         5 - 10         82            90            93
#
# [22343 rows x 10 columns]

# %%
type(data["Noofsiblings"][0]) ## checking the datatype of the column Noofsiblings
# Out:
# numpy.float64

# %%
data["Noofsiblings"] =  data["Noofsiblings"].astype(int)

# %%
data
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  Noofsiblings  \
# 0           1     group B     master's degree      standard             4
# 1           0     group C        some college      standard             0
# 2           1     group B  associate's degree      standard             1
# 3           1     group B        some college      standard             1
# 4           0     group B        some college  free/reduced             1
# ...       ...         ...                 ...           ...           ...
# 22338       0     group A  associate's degree  free/reduced             2
# 22339       0     group C        some college      standard             2
# 22340       1     group D         high school      standard             2
# 22341       0     group E         high school      standard             1
# 22342       1     group D  associate's degree      standard             3
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         87            93            91
# 1         school_bus         5 - 10         76            78            75
# 2         school_bus         5 - 10         73            84            79
# 3            private         5 - 10         85            93            89
# 4            private           > 10         41            43            39
# ...              ...            ...        ...           ...           ...
# 22338     school_bus         5 - 10         65            60            60
# 22339     school_bus         5 - 10         58            53            49
# 22340     school_bus         5 - 10         59            61            65
# 22341        private         5 - 10         58            53            51
# 22342     school_bus         5 - 10         82            90            93
#
# [22343 rows x 10 columns]

# %% [markdown]
# Now our Data cleaning is done. It is time to export the cleaned data

# %%
data.to_excel("Cleaned_data.xlsx")

# %%
data.to_csv("Cleaned_data.csv")

# %% [markdown]
# ## Thank you
